# %% [markdown]
# <a href="https://colab.research.google.com/github/italomarcelogit/python.free/blob/master/NLP_SPACY_VADER_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install feedparser
import feedparser
# Out:
# Collecting feedparser
#   Downloading https://files.pythonhosted.org/packages/2c/84/df6de99cba01afc82344c9cb3a79df100a00ac33396120f8aa66c72f0d84/feedparser-6.0.1-py2.py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 2.2MB/s
# Collecting sgmllib3k
#   Downloading https://files.pythonhosted.org/packages/9e/bd/3704a8c3e0942d711c1299ebf7b9091930adae6675d7c8f476a7ce48653c/sgmllib3k-1.0.0.tar.gz
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-cp36-none-any.whl size=6067 sha256=5e9365edf7b33af0e47124e2d1fe5af117d37072e142a1b94ed9d32ec3b37d5f
#   Stored in directory: /root/.cache/pip/wheels/f1/80/5a/444ba08a550cdd241bd9baf8bae44be750efe370adb944506a
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.1 sgmllib3k-1.0.0

# %%
# !pip install vaderSentiment
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# Collecting vaderSentiment
#   Downloading https://files.pythonhosted.org/packages/76/fc/310e16254683c1ed35eeb97386986d6c00bc29df17ce280aed64d55537e9/vaderSentiment-3.3.2-py2.py3-none-any.whl (125kB)
#      |████████████████████████████████| 133kB 2.8MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (3.0.4)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
phrases = [
"I would feel the same in your situation, but we will sort this out",
"I know how frustrating it can be – let’s see how I can help you",
"I completely understand how frustrating it is",
"I appreciate how difficult it is",
"We will work to resolve the problem. You just enjoy your (birthday/holidays/Christmas break, etc.), and I will be in touch shortly.",
"We are keen to resolve this as much as you are",
"If I were in your position, I would feel exactly the same",
"I appreciate you bringing this to our attention…",
"I will contact you as soon as we have had an update.",
"Definitely, you are making perfect sense.",
"I can assure you that this will absolutely happen.",
"We will help you get this issue resolved.",
"Apologies for the wait, I appreciate your patience.",
"Don’t worry, I can see why you did that.",
"Yes, that would certainly frustrate me too.",
"What I would do in this situation i"
"How do you feel about fear",
"I know others who have been in your situation and what we did to successfully help them",
"Just so we know what we’re aiming for, what would be the best-case scenario for you.",
"Absolutely, I can certainly fix that for you.",
"I will quickly put this into action for you and then everything will be back to normal.",
"Just so I can clarify and help you.",
"I’m afraid that we cannot offer you X, but what I can do for you",
"I am going to take care of this for you.",
"That does sound frustrating, let’s see what I can do to help.",    
"I love the team and how they played last night 💘" ,
"What a fine day I am having today :-) :-)",
"I am laughing like crazy lol",
"He was not very good at the play",
"He is kinda bored",
]

readSentiment = SentimentIntensityAnalyzer()

# %%
for txt in phrases:
  print(readSentiment.polarity_scores(txt))
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.156, 'neu': 0.699, 'pos': 0.145, 'compound': -0.0516}
# {'neg': 0.345, 'neu': 0.655, 'pos': 0.0, 'compound': -0.4877}
# {'neg': 0.272, 'neu': 0.435, 'pos': 0.293, 'compound': 0.0516}
# {'neg': 0.102, 'neu': 0.679, 'pos': 0.219, 'compound': 0.4767}
# {'neg': 0.0, 'neu': 0.638, 'pos': 0.362, 'compound': 0.6249}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.385, 'pos': 0.615, 'compound': 0.7506}
# {'neg': 0.0, 'neu': 0.769, 'pos': 0.231, 'compound': 0.34}
# {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'compound': 0.5267}
# {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019}
# {'neg': 0.266, 'neu': 0.734, 'pos': 0.0, 'compound': -0.4404}
# {'neg': 0.248, 'neu': 0.331, 'pos': 0.421, 'compound': 0.2732}
# {'neg': 0.211, 'neu': 0.789, 'pos': 0.0, 'compound': -0.4939}
# {'neg': 0.0, 'neu': 0.718, 'pos': 0.282, 'compound': 0.7096}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.724, 'pos': 0.276, 'compound': 0.3947}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019}
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.4939}
# {'neg': 0.186, 'neu': 0.641, 'pos': 0.173, 'compound': -0.0516}
# {'neg': 0.0, 'neu': 0.481, 'pos': 0.519, 'compound': 0.8957}
# {'neg': 0.0, 'neu': 0.522, 'pos': 0.478, 'compound': 0.6597}
# {'neg': 0.186, 'neu': 0.155, 'pos': 0.659, 'compound': 0.7269}
# {'neg': 0.238, 'neu': 0.544, 'pos': 0.218, 'compound': -0.0574}
# {'neg': 0.376, 'neu': 0.624, 'pos': 0.0, 'compound': -0.204}

# %%
def getSentiment(phrase):
  s = readSentiment.polarity_scores(phrase)
  if s['compound'] <= -0.05:
    sentiment = 0
  elif s['compound'] >= 0.05:
    sentiment = 1
  else:
    sentiment = 2
  return sentiment, s

# %%
t1 = getSentiment("He is kinda bored")
t1
# Out:
# (0, {'compound': -0.204, 'neg': 0.376, 'neu': 0.624, 'pos': 0.0})

# %%
t1 = getSentiment("The book was good")
t1
# Out:
# (1, {'compound': 0.4404, 'neg': 0.0, 'neu': 0.508, 'pos': 0.492})

# %%
t1 = getSentiment("Taco's Tuesday")
t1
# Out:
# (2, {'compound': 0.0, 'neg': 0.0, 'neu': 1.0, 'pos': 0.0})

# %%
sentiments = ['Negative', 'Positive', 'Neutral']
for txt in phrases:
  print(sentiments[getSentiment(txt)[0]], ' - ', txt)
# Out:
# Neutral  -  I would feel the same in your situation, but we will sort this out
# Negative  -  I know how frustrating it can be – let’s see how I can help you
# Negative  -  I completely understand how frustrating it is
# Positive  -  I appreciate how difficult it is
# Positive  -  We will work to resolve the problem. You just enjoy your (birthday/holidays/Christmas break, etc.), and I will be in touch shortly.
# Positive  -  We are keen to resolve this as much as you are
# Neutral  -  If I were in your position, I would feel exactly the same
# Positive  -  I appreciate you bringing this to our attention…
# Neutral  -  I will contact you as soon as we have had an update.
# Positive  -  Definitely, you are making perfect sense.
# Positive  -  I can assure you that this will absolutely happen.
# Positive  -  We will help you get this issue resolved.
# Positive  -  Apologies for the wait, I appreciate your patience.
# Negative  -  Don’t worry, I can see why you did that.
# Positive  -  Yes, that would certainly frustrate me too.
# Negative  -  What I would do in this situation iHow do you feel about fear
# Positive  -  I know others who have been in your situation and what we did to successfully help them
# Neutral  -  Just so we know what we’re aiming for, what would be the best-case scenario for you.
# Positive  -  Absolutely, I can certainly fix that for you.
# Neutral  -  I will quickly put this into action for you and then everything will be back to normal.
# Positive  -  Just so I can clarify and help you.
# Neutral  -  I’m afraid that we cannot offer you X, but what I can do for you
# Positive  -  I am going to take care of this for you.
# Negative  -  That does sound frustrating, let’s see what I can do to help.
# Positive  -  I love the team and how they played last night 💘
# Positive  -  What a fine day I am having today :-) :-)
# Positive  -  I am laughing like crazy lol
# Negative  -  He was not very good at the play
# Negative  -  He is kinda bored

# %% [markdown]
# # **Online Texts**
#
# Let's get some news headlines (titles) on CNN and ESPN by RSS feeds

# %%
sources = [
          "http://rss.cnn.com/rss/edition_travel.rss",
          "http://rss.cnn.com/rss/edition_world.rss",
          "http://rss.cnn.com/rss/money_news_international.rss",
          "http://rss.cnn.com/rss/edition_technology.rss",
          "http://rss.cnn.com/rss/edition_entertainment.rss"
          'https://www.espn.com/espn/rss/nfl/news',
          'https://www.espn.com/espn/rss/nba/news',
          'https://www.espn.com/espn/rss/rpm/news',
          'https://www.espn.com/espn/rss/soccer/news',
          'https://www.espn.com/espn/rss/mlb/news',
          'https://www.espn.com/espn/rss/nhl/news',
          'https://www.espn.com/espn/rss/poker/master',
           'http://rss.cnn.com/rss/edition_sport.rss',
           'http://rss.cnn.com/rss/edition_football.rss',
           'http://rss.cnn.com/rss/cnn_latest.rss',
           'http://rss.cnn.com/rss/edition_space.rss',
           'http://rss.cnn.com/rss/edition.rss',
           'http://rss.cnn.com/rss/edition_africa.rss',
           'http://rss.cnn.com/rss/edition_americas.rss'

          
]
feeds = []
for s in sources:
  feed = feedparser.parse(s)
  feeds.append(feed)

# %%
titles = []
summaries = []
for feed in feeds:
  for content in feed.entries:
    titles.append(content.title)
    try:
      summaries.append(content.summary)
    except:
      summaries.append(content.title)

# %% [markdown]
# # **Sentiment analysis**

# %% [markdown]
# **Analysing TITLES**

# %%
for txt in titles:
  print(sentiments[getSentiment(txt)[0]], ' - ', txt)
# Out:
# Positive  -  Live like Rajasthani royalty at this 475-year-old palace hotel
# Neutral  -  World's largest overwater villas open in Maldives
# Positive  -  Dubai wide open for tourists. Here's what it's like to visit
# Neutral  -  Remembering a classic adult hotel playland
# Neutral  -  What's next for deluxe, all-you-can-eat buffets?
# Neutral  -  Inside North Korea's tourist hotels
# Neutral  -  Giant robot comes to life in Japan
# Negative  -  'The girls go crazy over him': Meet Mongolia's most eligible eagle hunter
# Neutral  -  Last ever Airbus A380 superjumbo almost finished
# Neutral  -  Tickets for Qantas flight to nowhere sell out in minutes
# Positive  -  These exotic destinations want remote workers
# Neutral  -  The pilots changing the face of aviation
# Neutral  -  A 20-year hunt to find an extinct fruit
# Neutral  -  Can airport testing and Covid immunity passports unlock travel?
# Neutral  -  The incredible tale of a man who formed an unlikely bond with an octopus
# Positive  -  Mexico hopes to revive tourism with Teotihuacan reopening
# Neutral  -  The countries that ceased to exist
# Neutral  -  Why passenger jets could soon be flying in formation
# Negative  -  Meet the first all-women ranger unit fighting poachers
# Negative  -  Amsterdam has been collapsing for years. Now it's paying the price
# Neutral  -  One woman, four men and weeks in Norway's Arctic ice
# Negative  -  'Price of blood': Financial London's grim history revealed
# Negative  -  Big scary chasm opens up in Flight Sim reboot
# Neutral  -
# Negative  -  No one wanted to travel with me, so I went on vacation with a total stranger
# Neutral  -  The incredible tale of a man who formed an unlikely bond with an octopus
# Neutral  -  Hundreds of millions of people in China are about to go on vacation at the same time
# Neutral  -
# Neutral  -  What's happening at Singapore's Changi Airport during Covid
# Neutral  -
# Negative  -  Australian man jailed after stomping on pregnant Muslim woman
# Negative  -  Rape ruled out by police in fatal attack of Indian teenager
# Negative  -  Analysis: NZ held a debate hours after Trump-Biden 'hot mess'
# Positive  -  What could happen after EU launched legal action against UK
# Positive  -  Secret daughter of ex-king wins the right to call herself a princess
# Neutral  -  In unusual move, FAA chief test flies 737 Max; says more fixes needed
# Negative  -  Wall Street is 'doomsday prepping' for the election
# Negative  -  Elon Musk doubles down on Covid-19 skepticism and says he won't take future vaccine
# Negative  -  Trump is stealing China's playbook to deal with TikTok
# Neutral  -  How a startup became one of India's biggest health platforms
# Negative  -  US cities are losing 36 million trees a year. Here's why it matters
# Neutral  -  Miami's Little Haiti wasn't a target for developers. Until the seas started to rise
# Positive  -  How rich people could help save the planet from the climate crisis
# Neutral  -  Rare photos of 19th-century China
# Positive  -  Adult playgrounds help lift spirits
# Neutral  -  Chinese wine vessel found in garage sells for $500K
# Neutral  -  The one item of clothing in every genius' closet
# Neutral  -  Inside Drake's extravagant home
# Positive  -  Germany's ex-royals want their riches back, but past ties to Hitler stand in the way
# Neutral  -  Naomi Campbell says Africa 'has been so untapped'
# Positive  -  Confessions of a VIP private jet flight attendant
# Neutral  -  Last ever A380 superjumbo is almost done
# Neutral  -  China takes on Airbus and Boeing
# Neutral  -  Mysterious 'bullet' plane is finally revealed
# Neutral  -  Why passenger jets could soon be flying in formation
# Neutral  -  Scientists say they've figured the odds of catching Covid-19 on a plane
# Positive  -  89-year-old delivery driver surprised with $12,000 tip
# Positive  -  Bridge inspector rescues dog stranded 120 feet above Mississippi River
# Positive  -  A year of free subway rides for a man who chased down and captured train derailment suspect
# Negative  -  Mexico ready to retaliate by hurting US farmers
# Neutral  -  Will the next iPhone charge wirelessly?
# Neutral  -  How 'America First' could turn into to 'India First'
# Negative  -  Swiss voters reject corporate tax overhaul
# Neutral  -  Stocks hit record again. Is Trump the reason?
# Neutral  -  Apple stock nears record high
# Neutral  -  America's NAFTA nemesis: Canada, not Mexico
# Positive  -  Verizon's plan: Consumers win, investors lose
# Neutral  -  Oil prices have doubled in a year. Here's why
# Neutral  -  Tesla will sell electric cars in the Middle East
# Neutral  -  Indian rival slams Uber's business model
# Negative  -  Cook calls for campaign against fake news
# Neutral  -  Trump brand takes another hit
# Negative  -  Cutting down trash with bamboo packaging
# Positive  -  Nike stars champion 'Equality' in new ad
# Positive  -  'Lego Batman' producer, then Treasury sec?
# Negative  -  Are we heading for another Greek debt crisis?
# Neutral  -  Verizon is bringing back unlimited data
# Negative  -  Visa crackdown puts these rural doctors at risk
# Positive  -  Trump isn't killing the bull market. Here's why
# Negative  -  How to outsmart fake news in your Facebook feed
# Positive  -  Revealed: Winners of the 'Oscars of watches'
# Neutral  -  Driverless 'Roborace' car makes street track debut
# Neutral  -  Flying a sports car with wings
# Positive  -  Brightest supermoon since 1948
# Neutral  -  This NASA astronaut voted from space
# Neutral  -  Teen girls prepare for space launch
# Negative  -  Going to space is a real pain in the back
# Negative  -  Russian gamers race to prevent nuclear 'war'
# Positive  -  What parents should know about the VR gear kids want
# Negative  -  Japan's boom in weird wearable tech
# Neutral  -  Cell phones, screens are keeping your kid awake
# Neutral  -  Your first look at Jim Carrey as Joe Biden on 'SNL' has arrived
# Neutral  -  'The Rock,' LeBron and Scott Baio all have 1 thing in common
# Neutral  -  See what's streaming in October
# Neutral  -  Watch Meryl Streep read a poem from John Lithgow's 'Trumpty Dumpty' book
# Positive  -  Lenny Kravitz perfectly sums up his friendship with Jason Momoa
# Neutral  -  Blackpink discuss working with their music idols Cardi B and Selena Gomez
# Positive  -  'On the Rocks' features Bill Murray in a pleasant 'Lost in Translation' reunion
# Positive  -  'The Glorias' follows Gloria Steinem's fascinating life
# Negative  -  'Kingdom of Silence' revisits Jamal Khashoggi's death and the history of US-Saudi relations
# Neutral  -  'The Boys in the Band' brings the Tony-winning stage revival to Netflix
# Negative  -  'Weird Al' Yankovic mocks presidential debate in 'We're All Doomed'
# Positive  -  Kristin Cavallari currently working on dropping Cutler from legal name
# Neutral  -  Atlanta exotic dancers 'Get Your Booty to the Poll' PSA grabs attention
# Neutral  -  Drew Barrymore kept this 'E.T.' prop
# Neutral  -  2020 MLB playoffs: Why this could be the wildest postseason ... ever
# Negative  -  How empty ballparks would have changed MLB history -- and could alter games this October
# Neutral  -  Mike Trout tracker, Mr. October edition: Would he trade careers with Reggie Jackson?
# Neutral  -  MLB players who break the internet: The most meme-worthy on each likely playoff team
# Neutral  -  NHL goaltender carousel: Where Holtby, Lundqvist and more could land
# Positive  -  Ranking the NHL's top 60 (plus) 2020 free agents into tiers
# Positive  -  Alex Pietrangelo's savvy 'local hero' pressure play on the Blues
# Neutral  -  NHL draft season trade preview: What we're hearing on Laine, Eichel and more
# Neutral  -  Hurricanes, Svechnikov in talks about extension
# Positive  -  Lightning say Stamkos will be ready for 2020-21
# Positive  -  Lightning celebrate title with parade, ceremony
# Positive  -  Lamoriello optimistic Isles will stay mostly intact
# Neutral  -  Buyout ends Lundqvist's tenure with Rangers
# Negative  -  Lightning fan's 'Shoot!' mix-up turns into big score
# Negative  -  Stars left numb after postseason run falls short
# Positive  -  What will the next NHL bubbles look like?
# Negative  -  Winners and losers of the 2020 NHL playoff bubbles
# Neutral  -  NHL bubble confidential: Go inside the Toronto and Edmonton playoff hubs
# Positive  -  2020 NHL draft final rankings: Top 100 prospects
# Negative  -  NHL best-case mock draft: How each team aces the first two rounds
# Positive  -  Top NHL draft defense prospects break down their own scouting reports
# Neutral  -  Biggest takeaways from 'Quest for the Stanley Cup' Episode 5
# Positive  -  'You're not alone': Tyler Motte hopes to inspire others to discuss their mental health
# Positive  -  How the Lightning learned to be Stanley Cup champions
# Neutral  -  Keys to the offseason: Free-agency, draft plans for all 31 NHL teams
# Positive  -  How the Tampa Bay Lightning built a perennial contender
# Neutral  -  Postseason baseball, this is Fernando Tatis Jr.
# Positive  -  Kershaw has 'fun night,' K's 13 as Dodgers sweep
# Positive  -  Sources: Rivers agrees to 5-year deal with 76ers
# Neutral  -  QB Rypien leads Broncos past Jets in first start
# Positive  -  LeBron boils down success with AD: No jealousy
# Positive  -  Tatis, Myers hit 2 HRs each to join Ruth, Gehrig
# Neutral  -  Pats' Newton: Mahomes 'changing the game'
# Neutral  -  Ben Simmons and Joel Embiid could give Doc Rivers deja vu
# Neutral  -  The King, The Architect and the GOAT: The ties that bind the Lakers and Heat
# Neutral  -  MLB Playoff Daily: Cubs-Marlins, Padres-Cardinals take center stage
# Neutral  -  Looking for some playoff spice? Why heated Astros-A's is the series for you
# Negative  -  Sports cards are back in a big way -- pandemic, recession and all
# Positive  -  WNBA Finals 2020 Roundtable: Predicting who wins Aces-Storm and why
# Negative  -  Three generations later, the secrets of Wichita State's devastating plane crash are still unfolding
# Positive  -  Motivated Cam Newton calls joining Patriots a 'business trip'
# Negative  -  The NFL is taking the coronavirus seriously. Are the teams? Why this week was a wake-up call
# Neutral  -  Week 4 Love/Hate: The definitive Matthew Berry guide to trading in fantasy football
# Positive  -  Champions League group reaction: Messi vs. Ronaldo the highlight, Man United face grueling group
# Positive  -  They're not thieves, they're coaches
from  spacy.lang.en.stop_words import STOP_WORDS
nlp = spacy.load('en_core_web_sm')
import re
import string

# %%
def cleaningText(original, show=False):
  txt = original
  txt = txt.lower() # lowercase
  txt = re.sub('@','',txt) # remove @ 
  txt = re.sub('\[.*\]','',txt) # remove contents between brackets
  txt = re.sub('<.*?>+','',txt) # remove contents between less and more signs
  txt = re.sub('https?://\S+|www\.\S+', '', txt) # remove URLs
  txt = re.sub(re.escape(string.punctuation), '', txt) # remove punctuation
  txt = re.sub(r'[^a-zA-Z ]+', '', txt) # remove numbers
  txt = re.sub('\n', '', txt) # remove line break
  txt = str(txt).strip()
  if show:
    print('ORIGINAL: ', original)
    print('   TEXT CLEANNED: ', txt)
  return txt

# %%
titlesClean = [cleaningText(title) for title in titles]

# %%
for txt in titlesClean:
  print(sentiments[getSentiment(txt)[0]], ' - ', txt)
# Out:
# Positive  -  live like rajasthani royalty at this yearold palace hotel
# Neutral  -  worlds largest overwater villas open in maldives
# Positive  -  dubai wide open for tourists heres what its like to visit
# Neutral  -  remembering a classic adult hotel playland
# Neutral  -  whats next for deluxe allyoucaneat buffets
# Neutral  -  inside north koreas tourist hotels
# Neutral  -  giant robot comes to life in japan
# Negative  -  the girls go crazy over him meet mongolias most eligible eagle hunter
# Neutral  -  last ever airbus a superjumbo almost finished
# Neutral  -  tickets for qantas flight to nowhere sell out in minutes
# Positive  -  these exotic destinations want remote workers
# Neutral  -  the pilots changing the face of aviation
# Neutral  -  a year hunt to find an extinct fruit
# Neutral  -  can airport testing and covid immunity passports unlock travel
# Neutral  -  the incredible tale of a man who formed an unlikely bond with an octopus
# Positive  -  mexico hopes to revive tourism with teotihuacan reopening
# Neutral  -  the countries that ceased to exist
# Neutral  -  why passenger jets could soon be flying in formation
# Negative  -  meet the first allwomen ranger unit fighting poachers
# Negative  -  amsterdam has been collapsing for years now its paying the price
# Neutral  -  one woman four men and weeks in norways arctic ice
# Negative  -  price of blood financial londons grim history revealed
# Negative  -  big scary chasm opens up in flight sim reboot
# Neutral  -
# Negative  -  no one wanted to travel with me so i went on vacation with a total stranger
# Neutral  -  the incredible tale of a man who formed an unlikely bond with an octopus
# Neutral  -  hundreds of millions of people in china are about to go on vacation at the same time
# Neutral  -
# Neutral  -  whats happening at singapores changi airport during covid
# Neutral  -
# Negative  -  australian man jailed after stomping on pregnant muslim woman
# Negative  -  rape ruled out by police in fatal attack of indian teenager
# Negative  -  analysis nz held a debate hours after trumpbiden hot mess
# Positive  -  what could happen after eu launched legal action against uk
# Positive  -  secret daughter of exking wins the right to call herself a princess
# Neutral  -  in unusual move faa chief test flies  max says more fixes needed
# Negative  -  wall street is doomsday prepping for the election
# Negative  -  elon musk doubles down on covid skepticism and says he wont take future vaccine
# Negative  -  trump is stealing chinas playbook to deal with tiktok
# Neutral  -  how a startup became one of indias biggest health platforms
# Negative  -  us cities are losing  million trees a year heres why it matters
# Neutral  -  miamis little haiti wasnt a target for developers until the seas started to rise
# Positive  -  how rich people could help save the planet from the climate crisis
# Neutral  -  rare photos of thcentury china
# Positive  -  adult playgrounds help lift spirits
# Neutral  -  chinese wine vessel found in garage sells for k
# Neutral  -  the one item of clothing in every genius closet
# Neutral  -  inside drakes extravagant home
# Positive  -  germanys exroyals want their riches back but past ties to hitler stand in the way
# Neutral  -  naomi campbell says africa has been so untapped
# Positive  -  confessions of a vip private jet flight attendant
# Neutral  -  last ever a superjumbo is almost done
# Neutral  -  china takes on airbus and boeing
# Neutral  -  mysterious bullet plane is finally revealed
# Neutral  -  why passenger jets could soon be flying in formation
# Neutral  -  scientists say theyve figured the odds of catching covid on a plane
# Positive  -  yearold delivery driver surprised with  tip
# Positive  -  bridge inspector rescues dog stranded  feet above mississippi river
# Positive  -  a year of free subway rides for a man who chased down and captured train derailment suspect
# Negative  -  mexico ready to retaliate by hurting us farmers
# Neutral  -  will the next iphone charge wirelessly
# Neutral  -  how america first could turn into to india first
# Negative  -  swiss voters reject corporate tax overhaul
# Neutral  -  stocks hit record again is trump the reason
# Neutral  -  apple stock nears record high
# Neutral  -  americas nafta nemesis canada not mexico
# Positive  -  verizons plan consumers win investors lose
# Neutral  -  oil prices have doubled in a year heres why
# Neutral  -  tesla will sell electric cars in the middle east
# Neutral  -  indian rival slams ubers business model
# Negative  -  cook calls for campaign against fake news
# Neutral  -  trump brand takes another hit
# Negative  -  cutting down trash with bamboo packaging
# Positive  -  nike stars champion equality in new ad
# Positive  -  lego batman producer then treasury sec
# Negative  -  are we heading for another greek debt crisis
# Neutral  -  verizon is bringing back unlimited data
# Negative  -  visa crackdown puts these rural doctors at risk
# Positive  -  trump isnt killing the bull market heres why
# Negative  -  how to outsmart fake news in your facebook feed
# Positive  -  revealed winners of the oscars of watches
# Neutral  -  driverless roborace car makes street track debut
# Neutral  -  flying a sports car with wings
# Positive  -  brightest supermoon since
# Neutral  -  this nasa astronaut voted from space
# Neutral  -  teen girls prepare for space launch
# Negative  -  going to space is a real pain in the back
# Negative  -  russian gamers race to prevent nuclear war
# Positive  -  what parents should know about the vr gear kids want
# Negative  -  japans boom in weird wearable tech
# Neutral  -  cell phones screens are keeping your kid awake
# Neutral  -  your first look at jim carrey as joe biden on snl has arrived
# Neutral  -  the rock lebron and scott baio all have  thing in common
# Neutral  -  see whats streaming in october
# Neutral  -  watch meryl streep read a poem from john lithgows trumpty dumpty book
# Positive  -  lenny kravitz perfectly sums up his friendship with jason momoa
# Neutral  -  blackpink discuss working with their music idols cardi b and selena gomez
# Positive  -  on the rocks features bill murray in a pleasant lost in translation reunion
# Positive  -  the glorias follows gloria steinems fascinating life
# Negative  -  kingdom of silence revisits jamal khashoggis death and the history of ussaudi relations
# Neutral  -  the boys in the band brings the tonywinning stage revival to netflix
# Negative  -  weird al yankovic mocks presidential debate in were all doomed
# Positive  -  kristin cavallari currently working on dropping cutler from legal name
# Neutral  -  atlanta exotic dancers get your booty to the poll psa grabs attention
# Neutral  -  drew barrymore kept this et prop
# Positive  -  the bachelorette host chris harrison promises the most explosive season fans have ever seen
# Neutral  -  donald glover privately had a new son and named him after his late father
# Neutral  -  barry jenkins to direct lion king followup
# Positive  -  shannen doherty shares update on her health
# Neutral  -  avatar  is nearly done filming
# Positive  -  chadwick boseman cut his own salary to increase sienna millers on  bridges
# Neutral  -  mariah carey reveals she once recorded an alternative album
# Positive  -  taylor swift tops a whitney houston billboard record
# Neutral  -  carole baskin is eliminated from dancing with the stars
# Neutral  -  bts will release new album in november
# Positive  -  woke draws humor from a black cartoonists political awakening
# Neutral  -  secret society of secondborn royals gives disney an xmenlike franchise
# Neutral  -  the comey rule shows off a sensational cast in a slightly uneven miniseries
# Positive  -  drew barrymore has nothing to hide as she launches her new talk show
# Positive  -  the west wings idealism looks even better  years after its first emmy
# Neutral  -  the way i see it filters the obama presidency through pete souzas lens
# Neutral  -  ben simmons and joel embiid could give doc rivers deja vu
# Positive  -  sources rivers agrees to year deal with ers
# Positive  -  lebron boils down success with ad no jealousy
# Neutral  -  irving kd say nets coaching will be collaborative
# Negative  -  heats dragic adebayo doubtful for game
# Positive  -  ainge walker definitely not himself in bubble
# Positive  -  vince carter honored with sportsmanship award
# Positive  -  theyre not thieves theyre coaches
# Neutral  -  chris bosh watches game  with lebron heat on the mind
# Neutral  -  add it to the list herro ball joins iconic sports frenzies
# Positive  -  lowe on nba finals predicting who wins lakersheat and why
# Negative  -  what went wrong for doc rivers and the clippers
# Positive  -  steve ballmer was too used to winning to keep things the same
# Neutral  -  how the nba navigated its longest most unpredictable year
# Negative  -  jimmy butler and the heat are caught in a barista battle in the nba bubble
# Negative  -  honda to leave f at end of  season
# Positive  -  dixon honda look to wrap up championships
# Neutral  -  castroneves follows new path in return to indy
# Neutral  -  indycar adds nashville to race  schedule
# Neutral  -  steve torrence beats dad at nhra gatornationals
# Positive  -  millican tops qualifying at nhra gatornationals
# Neutral  -  hinchcliffe fills andretti vacancy to finish season
# Neutral  -  helio to fill in for askew for indycar twinbill at ims
# Neutral  -  schumacher ilott and schwartzman complete ferrari test at fiorano
# Neutral  -  schumacher to make f debut at eifel gp
# Positive  -  hamilton vows to keep learning and growing after fia comments
# Positive  -  horner red bull seek to gain on merc errors
# Negative  -  fia counter hamiltons trying to stop me claim
# Neutral  -  bottas explains to whom it may concern radio message
# Negative  -  fia rescinds hamiltons sochi penalty points
# Negative  -  hamilton says ridiculous penalties aimed at stopping him
# Negative  -  hamilton close to race ban after russian gp penalties
# Neutral  -  fia moves to rule out repeat of hamiltons breonna taylor tshirt
# Positive  -  hamilton still faces big challenge to secure st win
# Neutral  -  wolff doubts ferrari would have accepted him as f boss
# Positive  -  mick schumacher hopes to claim f win record from hamilton in future
# Positive  -  best bets for south point
# Neutral  -  f confirms domenicali will replace carey as ceo in
# Neutral  -  european kit power rankings which ucl uel giant is most stylish
# Positive  -  champions league group reaction messi vs ronaldo the highlight
# Positive  -  solskjaer man utd squad depth strong enough
# Positive  -  arteta arsenal have reached crucial moment
# Positive  -  milan win penalty epic to reach europa stage
# Negative  -  rising place coach player on leave amid probe
# Negative  -  sources rugani to snub prem clubs for rennes
# Neutral  -  arsenal host man city in carabao cup quarters
# Positive  -  fati messi strike as man barcelona win again
# Neutral  -  transfer talk psg send arsenals aouar bid into tailspin
# Positive  -  dest cherki bellingham  starlets poised for breakthrough seasons
# Positive  -  mls midseason awards columbus crew rossi pozuelo atlanta united all take home hardware
# Positive  -  everton are perfect in premier league this season how have they done it and how far can they go
# Neutral  -  liverpool exit arsenal progression the result both teams needed
# Neutral  -  coutinho  as man barca show their grit at celta
# Negative  -  mexico club america coaches spat comes ahead of tricky time for el tri
# Neutral  -  suarez fati epitomise la ligas blend of golden oldies and young stars
# Positive  -  transfer window countdown man united need help barcelona rebuild
# Negative  -  english football on the brink premier league weathering storm of no fans but lower leagues are in trouble
# Positive  -  best forfeit ever fantasy premier league loser becomes statue on streets of london
# Positive  -  mata leads man united into carabao cup quarters
# Positive  -  mou gets last laugh on lampard as spurs eliminate chelsea in shootout
# Negative  -  vinicius  as madrid survive a scare from valladolid
# Positive  -  usmnt and the bundesliga why so many top young americans choose germany on career path
# Positive  -  why aouar would be the perfect signing for artetas arsenal project
# Neutral  -  cameroons sydney  legends where are they now
# Neutral  -  cant even watch that game again  foudy on sydney
# Neutral  -  postseason baseball this is fernando tatis jr
# Neutral  -  as oust white sox to end year playoff funk
# Positive  -  tatis myers hit  hrs each to join ruth gehrig
# Neutral  -  braves take selfies to mark end of playoff woes
# Neutral  -  stanton says yanks have not done anything yet
# Neutral  -  astros ace verlander has tommy john surgery
# Neutral  -  hall of famer bench to auction memorabilia
# Positive  -  wild card thursday takeaways tatis padres come alive kershaw dominates
# Neutral  -  looking for some playoff spice heated astrosas alds is the series for you
# Neutral  -  why yankeesrays alds could be the series of the mlb playoffs
# Negative  -  twins torture breaking down their record game postseason losing streak
# Negative  -  will there be an upset can anyone beat la jeff passan weighs in
# Neutral  -  a case for fernando tatis jr as the mlb latino face of the s
# Positive  -  hispanic heritage month roberto clemente tops list of baseballs legendary latino faces
# Neutral  -  mlb playoffs why this could be the wildest postseason  ever
# Negative  -  how empty ballparks would have changed mlb history  and could alter games this october
# Neutral  -  mike trout tracker mr october edition would he trade careers with reggie jackson
# Neutral  -  mlb players who break the internet the most memeworthy on each likely playoff team
# Neutral  -  nhl goaltender carousel where holtby lundqvist and more could land
# Positive  -  ranking the nhls top  plus  free agents into tiers
# Positive  -  alex pietrangelos savvy local hero pressure play on the blues
# Neutral  -  nhl draft season trade preview what were hearing on laine eichel and more
# Neutral  -  hurricanes svechnikov in talks about extension
# Positive  -  lightning say stamkos will be ready for
# Positive  -  lightning celebrate title with parade ceremony
# Positive  -  lamoriello optimistic isles will stay mostly intact
# Neutral  -  buyout ends lundqvists tenure with rangers
# Negative  -  lightning fans shoot mixup turns into big score
# Negative  -  stars left numb after postseason run falls short
# Positive  -  what will the next nhl bubbles look like
# Negative  -  winners and losers of the  nhl playoff bubbles
# Neutral  -  nhl bubble confidential go inside the toronto and edmonton playoff hubs
# Positive  -  nhl draft final rankings top  prospects
# Negative  -  nhl bestcase mock draft how each team aces the first two rounds
# Positive  -  top nhl draft defense prospects break down their own scouting reports
# Neutral  -  biggest takeaways from quest for the stanley cup episode
# Positive  -  youre not alone tyler motte hopes to inspire others to discuss their mental health
# Positive  -  how the lightning learned to be stanley cup champions
# Neutral  -  keys to the offseason freeagency draft plans for all  nhl teams
# Positive  -  how the tampa bay lightning built a perennial contender
# Neutral  -  postseason baseball this is fernando tatis jr
# Positive  -  kershaw has fun night ks  as dodgers sweep
# Positive  -  sources rivers agrees to year deal with ers
# Neutral  -  qb rypien leads broncos past jets in first start
# Positive  -  lebron boils down success with ad no jealousy
# Positive  -  tatis myers hit  hrs each to join ruth gehrig
# Neutral  -  pats newton mahomes changing the game
# Neutral  -  ben simmons and joel embiid could give doc rivers deja vu
# Neutral  -  the king the architect and the goat the ties that bind the lakers and heat
# Neutral  -  mlb playoff daily cubsmarlins padrescardinals take center stage
# Neutral  -  looking for some playoff spice why heated astrosas is the series for you
# Negative  -  sports cards are back in a big way  pandemic recession and all
# Positive  -  wnba finals  roundtable predicting who wins acesstorm and why
# Negative  -  three generations later the secrets of wichita states devastating plane crash are still unfolding
# Positive  -  motivated cam newton calls joining patriots a business trip
# Negative  -  the nfl is taking the coronavirus seriously are the teams why this week was a wakeup call
# Neutral  -  week  lovehate the definitive matthew berry guide to trading in fantasy football
# Positive  -  champions league group reaction messi vs ronaldo the highlight man united face grueling group
# Positive  -  theyre not thieves theyre coaches
# Neutral  -  how far can mike leach air raid go this time itll have to go beyond lsu
# Positive  -  the sec is ready to give us the college football weekend weve been waiting for
# Neutral  -  guide to every week  nfl game picks matchup nuggets more
# Neutral  -  rock tweet says xfl plans to return in
# Negative  -  nfl steelerstitans wont be played in week
# Positive  -  barca sign usmnt defender sergino dest
# Positive  -  seeking a spark georgia keeps options open at quarterback
# Negative  -  biggest injury questions for every team whats next for michael thomas george kittle and others
# Neutral  -  athletes unlimited the beginning cat ostermans final act
# Neutral  -  odds for the th preakness stakes
# Neutral  -  real or not furywilder iii without fans will taylorramirez finally happen
# Neutral  -  obama pops up as virtual spectator at nba finals
# Neutral  -  both goalkeepers miss as ac milan wins marathon penalty shootout
# Negative  -  san diego loyal walks off pitch after alleged homophobic abuse of gay player
# Positive  -  ronaldo pitted against messi in champions league group stage draw
# Negative  -  additional covid cases force nfl to move postponed game to later in season
# Negative  -  kipchoge will wear nikes controversial shoe at the london marathon
# Positive  -  messi says he only wanted to make barcelona better and stronger
# Neutral  -  mick schumacher to participate in a f race weekend for the first time
# Negative  -  when youve gotta go youve gotta go dier sprints off for emergency toilet break
# Positive  -  free diver discovers meaning to life exploring ocean depths
# Positive  -  totti visits fan who he helped wake up from coma
# Neutral  -  from world titles to the cover of vogue arabia
# Neutral  -  how an olympic image achieved immortality
# Neutral  -  star has no regrets over tshirts printed with seven bullet holes protest
# Negative  -  wouldnt give to a dog to chew players complain about new balls
# Neutral  -  the inside story of the ryder cups postponement
# Negative  -  he suffers from rare genetic condition but theres no stopping one in a million golfer
# Neutral  -  cases of covid have been linked to a karaoke bar in canada
# Positive  -  amazon tribes are using drones to track deforestation in brazil

# %%
import pandas as pd

# %%
sent = []
for txt in titles:
  sent.append(getSentiment(txt)[0])

dfT = pd.DataFrame()
dfT['title'] = titles
dfT['titleClean'] = titlesClean
dfT['sentimentTitle'] = sent

# %%
dfT.head()
# Out:
#                                                title  ... sentimentTitle
# 0  Live like Rajasthani royalty at this 475-year-...  ...              1
# 1  World's largest overwater villas open in Maldives  ...              2
# 2  Dubai wide open for tourists. Here's what it's...  ...              1
# 3         Remembering a classic adult hotel playland  ...              2
# 4   What's next for deluxe, all-you-can-eat buffets?  ...              2
#
# [5 rows x 3 columns]

# %%
dfTitle = dfT[['sentimentTitle','title']].groupby('sentimentTitle').count()
dfTitle
# Out:
#                 title
# sentimentTitle
# 0                 112
# 1                 142
# 2                 186

# %%
import plotly.express as px

# %%
colors=['orange', 'Darkblue', 'Darkred']
px.pie(names=sentiments, values=dfTitle.values, title='Sentiment Analysis - Titles', 
       color_discrete_sequence=colors)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a7e96c07-1e59-4f45-9525-91990e84b0fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7e96c07-1e59-4f45-9525-91990e84b0fe")) {
#                     Plotly.newPlot(
#                         'a7e96c07-1e59-4f45-9525-91990e84b0fe',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "label=%{label}<br>value=%{value}", "labels": ["Negative", "Positive", "Neutral"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [112, 142, 186]}],
#                         {"legend": {"tracegroupgap": 0}, "piecolorway": ["orange", "Darkblue", "Darkred"], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks ...

# %% [markdown]
# **Analysing Summaries**

# %%
summariesClean = [cleaningText(summary) for summary in summaries]

# %%
sent = []
for txt in summaries:
  sent.append(getSentiment(txt)[0])

dfS = pd.DataFrame()
dfS['summary'] = summaries
dfS['summaryClean'] = summariesClean
dfS['sentimentSummary'] = sent

# %%
dfSummary = dfS[['sentimentSummary','summary']].groupby('sentimentSummary').count()
dfSummary
# Out:
#                   summary
# sentimentSummary
# 0                     108
# 1                     203
# 2                     129

# %%
colors=['Darkblue', 'orange', 'Darkred']
px.pie(names=sentiments, values=dfSummary.values, title='Sentiment Analysis - Summaries', 
       color_discrete_sequence=colors)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="53be3eb7-6fc6-4219-883f-6bf00c6b010b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("53be3eb7-6fc6-4219-883f-6bf00c6b010b")) {
#                     Plotly.newPlot(
#                         '53be3eb7-6fc6-4219-883f-6bf00c6b010b',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "label=%{label}<br>value=%{value}", "labels": ["Negative", "Positive", "Neutral"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [108, 203, 129]}],
#                         {"legend": {"tracegroupgap": 0}, "piecolorway": ["Darkblue", "orange", "Darkred"], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks ...

# %% [markdown]
# **Conclusion 01**
#
# The news title brought a more neutral feeling than the summary. Depending on a newsroom, this can be a strategy.

# %% [markdown]
# **Analysing Words**

# %%
def tokenizeStr(original):
  txt2 = nlp(original) # creating a word's list
  txt2 = [token.lemma_ for token in txt2 if not nlp.vocab[token.text].is_stop]
  punct = string.punctuation
  stopwords = list(STOP_WORDS)
  ws = string.whitespace
  txt2 = [word for word in txt2 if word not in stopwords and word not in punct if len(word)>2]
  return txt2

# %%
# Example tokenizing sentence and 
tokenizeStr('Home sweet Home'), tokenizeStr("Choose a study category to start")
# Out:
# (['home', 'sweet', 'home'], ['choose', 'study', 'category', 'start'])

# %%
[a*b for b in range(1,3) for a in range(4,6)]
# Out:
# [4, 5, 8, 10]

# %%
wordsT = [word for i in range(0, len(dfT)-1) for word in tokenizeStr(dfT.iloc[i].titleClean) if str(word).strip() != '']
wordsTn = pd.value_counts(wordsT)

# %%
wordsS = [word for i in range(0, len(dfS)-1) for word in tokenizeStr(dfS.iloc[i].summaryClean) if str(word).strip() != '']
wordsSn = pd.value_counts(wordsS)

# %%
wordlist = pd.value_counts(wordsT+wordsS)

# %%
topW = pd.DataFrame(data={'tag': wordlist.index, 'count':wordlist.values})

# %%
topW[:10]
# Out:
#            tag  count
# 0        trump     63
# 1         year     55
# 2          new     51
# 3  coronavirus     44
# 4        covid     44
# 5          win     40
# 6       season     34
# 7     pandemic     32
# 8         test     32
# 9          man     31

# %%
px.bar(topW[:10], y='tag', x='count', orientation='h', 
       title='Top 10 words', color='tag')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="999f66b5-f3fd-4f6f-a559-4d63f3760b83" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("999f66b5-f3fd-4f6f-a559-4d63f3760b83")) {
#                     Plotly.newPlot(
#                         '999f66b5-f3fd-4f6f-a559-4d63f3760b83',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=trump", "marker": {"color": "#636efa"}, "name": "tag=trump", "offsetgroup": "tag=trump", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [63], "xaxis": "x", "y": ["trump"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=year", "marker": {"color": "#EF553B"}, "name": "tag=year", "offsetgroup": "tag=year", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [55], "xaxis": "x", "y": ["year"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=new", "marker": {"color": "#00cc96"}, "name": "tag=new", "offsetgroup": "tag=new", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [51], "xaxis": "x", "y": ["new"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=coronavirus", "marker": {"color": "#ab63fa"}, "name": "tag=coronavirus", "offsetgroup": "tag=coronavirus", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [44], "xaxis": "x", "y": ["coronavirus"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=covid", "marker": {"color": "#FFA15A"}, "name": "tag=covid", "offsetgroup": "tag=covid", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [44], "xaxis": "x", "y": ["covid"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=win", "marker": {"color": "#19d3f3"}, "name": "tag=win", "offsetgroup": "tag=win", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [40], "xaxis": "x", "y": ["win"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=season", "marker": {"color": "#FF6692"}, "name": "tag=season", "offsetgroup": "tag=season", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [34], "xaxis": "x", "y": ["season"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=pandemic", "marker": {"color": "#B6E880"}, "name": "tag=pandemic", "offsetgroup": "tag=pandemic", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [32], "xaxis": "x", "y": ["pandemic"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=test", "marker": {"color": "#FF97FF"}, "name": "tag=test", "offsetgroup": "tag=test", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [32], "xaxis": "x", "y": ["test"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "tag=%{y}<br>count=%{x}", "legendgroup": "tag=man", "marker": {"color": "#FECB52"}, "name": "tag=man", "offsetgroup": "tag=man", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [31], "xaxis": "x", "y": ["man"], "yaxis": "y"}],
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "tic

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

# %%
wordcloud = WordCloud(width = 800, height = 600, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(' '.join(dfT.title)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title('words from titles')
  
plt.show()

# %%
wordcloud = WordCloud(width = 800, height = 600, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(' '.join(dfS['summaryClean'])) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title('words from summaries')
  
plt.show()

# %% [markdown]
# **Only Positive in titles and summaries**

# %%
wordcloud = WordCloud(width = 800, height = 600, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(' '.join(dfT[dfT.sentimentTitle == 1].title)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title('words from titles - sentiment Positive')
  
plt.show()

# %%
wordcloud = WordCloud(width = 800, height = 600, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(' '.join(dfT[dfT.sentimentTitle == 0].title)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title('words from titles - sentiment negative')
  
plt.show()

# %%
wordcloud = WordCloud(width = 800, height = 600, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(' '.join(dfS[dfS.sentimentSummary == 1].summaryClean)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title('words from summaries - sentiment positive')
  
plt.show()

# %%
wordcloud = WordCloud(width = 800, height = 600, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(' '.join(dfS[dfS.sentimentSummary == 0].summaryClean)) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.title('words from summaries - sentiment negative')
  
plt.show()
